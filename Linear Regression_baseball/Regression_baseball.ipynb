# %% [markdown]
# ## Regression_Baseball

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## `1.` Read the dataset

# %%
# Read the data and show a small part of the dataframe to get an understaning of what is in there
bb = pd.read_csv('baseball.csv')
bb.head()
# Out:
#   Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  RankSeason  \
# 0  ARI     NL  2012  734  688  81  0.328  0.418  0.259         0         NaN
# 1  ATL     NL  2012  700  600  94  0.320  0.389  0.247         1         4.0
# 2  BAL     AL  2012  712  705  93  0.311  0.417  0.247         1         5.0
# 3  BOS     AL  2012  734  806  69  0.315  0.415  0.260         0         NaN
# 4  CHC     NL  2012  613  759  61  0.302  0.378  0.240         0         NaN
#
#    RankPlayoffs    G   OOBP   OSLG
# 0           NaN  162  0.317  0.415
# 1           5.0  162  0.306  0.378
# 2           4.0  162  0.315  0.403
# 3           NaN  162  0.331  0.428
# 4           NaN  162  0.335  0.424

# %% [markdown]
# b. Use the cell below to find the number of rows in the dataset.

# %%
# get the total number of rows in the dataframe
n_rows = bb.shape[0]
print('number of rows is :', n_rows)
# Out:
# number of rows is : 1232

# %% [markdown]
# c. The number of unique entries

# %%
# get the number of unique values in the year column
bb.Team.nunique()
# Out:
# 39

# %% [markdown]
# d. Describe the dataset

# %%
bb.describe()
# Out:
#               Year           RS           RA            W          OBP  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean   1988.957792   715.081981   715.081981    80.904221     0.326331
# std      14.819625    91.534294    93.079933    11.458139     0.015013
# min    1962.000000   463.000000   472.000000    40.000000     0.277000
# 25%    1976.750000   652.000000   649.750000    73.000000     0.317000
# 50%    1989.000000   711.000000   709.000000    81.000000     0.326000
# 75%    2002.000000   775.000000   774.250000    89.000000     0.337000
# max    2012.000000  1009.000000  1103.000000   116.000000     0.373000
#
#                SLG           BA     Playoffs  RankSeason  RankPlayoffs  \
# count  1232.000000  1232.000000  1232.000000  244.000000    244.000000
# mean      0.397342     0.259273     0.198052    3.122951      2.717213
# std       0.033267     0.012907     0.398693    1.738349      1.095234
# ...

# %% [markdown]
# e. get information on the dataset and dtypes

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 15 columns):
# Team            1232 non-null object
# League          1232 non-null object
# Year            1232 non-null int64
# RS              1232 non-null int64
# RA              1232 non-null int64
# W               1232 non-null int64
# OBP             1232 non-null float64
# SLG             1232 non-null float64
# BA              1232 non-null float64
# Playoffs        1232 non-null int64
# RankSeason      244 non-null float64
# RankPlayoffs    244 non-null float64
# G               1232 non-null int64
# OOBP            420 non-null float64
# OSLG            420 non-null float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 144.5+ KB

# %%
moneybb = bb[bb['Year']<2002]
moneybb.head()
# Out:
#     Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  \
# 330  ANA     AL  2001  691  730  75  0.327  0.405  0.261         0
# 331  ARI     NL  2001  818  677  92  0.341  0.442  0.267         1
# 332  ATL     NL  2001  729  643  88  0.324  0.412  0.260         1
# 333  BAL     AL  2001  687  829  63  0.319  0.380  0.248         0
# 334  BOS     AL  2001  772  745  82  0.334  0.439  0.266         0
#
#      RankSeason  RankPlayoffs    G   OOBP   OSLG
# 330         NaN           NaN  162  0.331  0.412
# 331         5.0           1.0  162  0.311  0.404
# 332         7.0           3.0  162  0.314  0.384
# 333         NaN           NaN  162  0.337  0.439
# 334         NaN           NaN  161  0.329  0.393

# %%
## create run difference column
moneybb['RD'] = moneybb['RS'] - moneybb['RA']
# Out:
# C:\Users\Mustafa Adel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
moneybb.head()
# Out:
#     Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  \
# 330  ANA     AL  2001  691  730  75  0.327  0.405  0.261         0
# 331  ARI     NL  2001  818  677  92  0.341  0.442  0.267         1
# 332  ATL     NL  2001  729  643  88  0.324  0.412  0.260         1
# 333  BAL     AL  2001  687  829  63  0.319  0.380  0.248         0
# 334  BOS     AL  2001  772  745  82  0.334  0.439  0.266         0
#
#      RankSeason  RankPlayoffs    G   OOBP   OSLG   RD
# 330         NaN           NaN  162  0.331  0.412  -39
# 331         5.0           1.0  162  0.311  0.404  141
# 332         7.0           3.0  162  0.314  0.384   86
# 333         NaN           NaN  162  0.337  0.439 -142
# 334         NaN           NaN  161  0.329  0.393   27

# %%
plt.scatter(moneybb.RD, moneybb.W);
plt.xlabel('Run Diff')
plt.ylabel('W')
# Out:
# Text(0, 0.5, 'W')

# %% [markdown]
# ## `2.` Apply linear regression model |

# %%
import statsmodels.api as sm
moneybb['intercept'] = 1
# apply linear regression model 
lm = sm.OLS(moneybb['W'],moneybb[['RD', 'intercept']])
result = lm.fit()
# Out:
# C:\Users\Mustafa Adel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      W   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     6651.
# Date:                Sat, 03 Oct 2020   Prob (F-statistic):               0.00
# Time:                        07:43:50   Log-Likelihood:                -2515.5
# No. Observations:                 902   AIC:                             5035.
# Df Residuals:                     900   BIC:                             5045.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RD             0.1058      0.001     81.554      0.000       0.103       0.108
# ...

# %%
## create a column that has the wins of each team in 2013 and rank
bb2012 = bb[bb['Year']==2012]

# %%
bb2012.head()
# Out:
#   Team League  Year   RS   RA   W    OBP    SLG     BA  Playoffs  RankSeason  \
# 0  ARI     NL  2012  734  688  81  0.328  0.418  0.259         0         NaN
# 1  ATL     NL  2012  700  600  94  0.320  0.389  0.247         1         4.0
# 2  BAL     AL  2012  712  705  93  0.311  0.417  0.247         1         5.0
# 3  BOS     AL  2012  734  806  69  0.315  0.415  0.260         0         NaN
# 4  CHC     NL  2012  613  759  61  0.302  0.378  0.240         0         NaN
#
#    RankPlayoffs    G   OOBP   OSLG
# 0           NaN  162  0.317  0.415
# 1           5.0  162  0.306  0.378
# 2           4.0  162  0.315  0.403
# 3           NaN  162  0.331  0.428
# 4           NaN  162  0.335  0.424

# %%
# dataframe with teams and wins in 2012
bb2012_tw = bb2012[['Team', 'W']]
bb2012_sorted = bb2012_tw.sort_values(by='W', ascending = False)
bb2012_sorted["Rank"] = bb2012_sorted["W"].rank() 
bb2012_sorted.head()
# Out:
#    Team   W  Rank
# 29  WSN  98  30.0
# 6   CIN  97  29.0
# 18  NYY  95  28.0
# 1   ATL  94  26.0
# 24  SFG  94  26.0

# %%
## correlation 
bb2012_sorted[['W', 'Rank']].corr()
# Out:
#              W      Rank
# W     1.000000  0.988517
# Rank  0.988517  1.000000
